# %% [markdown]
# # Data Visualization
#
# Author: Daniel Dills

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Displaying Seaborn's internal datasets

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %% [markdown]
# ## Import Data

# %%
tips = sns.load_dataset("tips")

# %% [markdown]
# ## Dataset information

# %%
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
X = tips["tip"].values
y = tips["total_bill"].values
z = tips["sex"].values

# %% [markdown]
# ### This particular graph takes a look at total bill and tip amount. While also taking into account whether the meal was at lunch or dinner, and whether the individual was a smoker or non-smoker.
#
#   1. For lunch time, at $20, they intersect and a non-smoker begins tipping more than their smoking counterparts.
#   2. There's a point where smokers typically tip more than their non-smoking counterparts, usually with smaller total bills. Then the non-smokers tip more, with the larger the bill.

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")

# %% [markdown]
# ### This particular categorical plot, takes into account tip amounts, and comparing Male and Females, while also taking into account whether they are smokers or not.
#
#   1. As you can see, on average, Men tip slightly more than their female counterparts, while Non-smoking counterparts also tip more.
#   2. For women, although they tip slightly less than their male counterparts, the change is that non-smoking women tip less than smokers.

# %%
sns.catplot(data=tips, kind="bar", x="sex", y="tip", hue="smoker")
